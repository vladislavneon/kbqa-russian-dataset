# %%
# %config IPCompleter.greedy=True
import pandas as pd
import json

# %%
data = pd.read_csv('properties_data.csv')

# %%
data.head()
# Out:
#     ID                    label  \
# 0   P6      глава правительства
# 1  P10                видеофайл
# 2  P14          знак автотрассы
# 3  P15        карта этой дороги
# 4  P16  система автомагистралей
#
#                                          description  \
# 0  высшее административное лицо, глава исполнител...
# 1              видеозапись, соответствующая элементу
# 2                      графическое изображение знака
# 3                  изображение карты для этой дороги
# 4  system (or specific country specific road type...
#
#                                              aliases      Data type  Count
# 0  бургомистр, глава администрации самоуправляемо...  wikibase-item  19453
# 1                запись видео, медиафайл, файл видео   commonsMedia   1990
# 2                                                NaN   commonsMedia  12077
# 3  автодорожная карта, железнодорожная карта, кар...   commonsMedia  16927
# 4                   дорожная система, сеть автодорог  wikibase-item  38122

# %% [markdown]
# ### Фильтрация по типу данных

# %%
data['Data type'].value_counts()
# Out:
# external-id          3437
# wikibase-item        1202
# quantity              478
# string                250
# url                    49
# commonsMedia           49
# time                   43
# monolingualtext        35
# math                   12
# wikibase-property      11
# wikibase-sense          9
# globe-coordinate        9
# wikibase-lexeme         8
# tabular-data            4
# wikibase-form           4
# geo-shape               2
# Name: Data type, dtype: int64

# %% [markdown]
# Уберем отношения:
#
#  - *external-id* - большинство из них содержит что-то специфическое;
#  - *commonsMedia* - медиафайлы
#  - *url* - ссылки
#  - *wikibase-property* - отношения между отношениями
#  - *tabular-data* - ссылки на таблицы
#  - *wikibase-form* - служебная информация
#  - *geo-shape* - геоданные

# %%
data = data[data['Data type'] != 'external-id']

data = data[data['Data type'] != 'commonsMedia']

data = data[data['Data type'] != 'url']

data = data[data['Data type'] != 'wikibase-property']

data = data[data['Data type'] != 'tabular-data']

data = data[data['Data type'] != 'wikibase-form']

data = data[data['Data type'] != 'geo-shape']

# %%
data_tagged = pd.read_csv('properties_data_wo_bad_datatypes_tagged.csv')

# %%
data_tagged = data_tagged[(data_tagged['Goodness'] == '1') | (data_tagged['Goodness'] == 'q')]

# %%
popular_and_good_properties = data_tagged[data_tagged['Goodness'] == '1']

# %%
popular_and_good_properties.head(500)
# Out:
#         ID Goodness                                           label  \
# 3     P577        1                                 дата публикации
# 6    P1545        1                                порядковый номер
# 9     P478        1                                             том
# 12     P17        1                                     государство
# 14    P131        1         административно-территориальная единица
# 16     P21        1                                  пол или гендер
# 17    P106        1                                     род занятий
# 18    P921        1                                   основная тема
# 19    P569        1                                   дата рождения
# 21    P735        1                                      личное имя
# 22     P27        1                                     гражданство
# 23     P50        1                                           автор
# 28     P19        1                                  место рождения
# 29    P570        1                                     дата смерти
# 31   P2044        1                         высота над уровнем моря
# 36    P571        1           дата основания/создания/возникновения
# 37    P734        1                                         фамилия
# 38    P585        1                                  момент времени
# 39    P580        1                                     дата начала
# 40    P641        1                                      вид спорта
# 42    P276        1                                 местонахождение
# 43   P1448        1                            официальное название
# 45    P495        1                            страна происхождения
# 46    P969        1                                           адрес
# 47     P20        1                                    место смерти
# 48     P69        1                               учебное заведение
# 49    P136        1                                            жанр
# 51   P1412        1     языки, на которых говорит или пишет персона
# 53    P155        1                           предыдущее по порядку
# 54    P156        1                            следующее по порядку
# ..     ...      ...                                             ...
# 639   P194        1                           законодательный орган
# 640   P912        1                                      оборудован
# 641  P1549        1                                     этнохороним
# 643  P5800        1                                нарративная роль
# 644  P3781        1                       имеет активный ингредиент
# 645   P113        1                                узловой аэропорт
# 646  P1373        1                       ежедневный пассажиропоток
# 647  P2175        1  применяется для лечения медицинского состояния
# 648  P1200        1                              категория бассейна
# 649   P726        1                                       кандидаты
# 650  P1560        1          вариант личного имени для другого пола
# 651   P129        1                               взаимодействует с
# 652   P465        1                цвет (шестнадцатеричный триплет)
# 653  P2700        1                                        протокол
# 655  P1410        1      количество мест в законодательном собрании
# 656   P504        1                                   основной порт
# 658   P803        1                                   учёное звание
# 660   P189        1                               место обнаружения
# 664  P1831        1                                       электорат
# 665  P1339        1                                   число раненых
# 668  P4792        1                                         плотина
# 670  P2275        1      международное непатентованное название ВОЗ
# 671  P1462        1                         орган по стандартизации
# 672  P4661        1                                   водохранилище
# 677   P741        1                                   играющая рука
# 679  P4969        1                              производная работа
# 681   P511        1                                  префикс титула
# 682  P1542        1                                        вызывает
# 683  P1750        1                                         именины
# 684  P2196        1                                  число учащихся
#
#                                            description  \
# 3        дата, когда произведение было выпущено в свет
# 6    позиция элемента в некоторой последовательност...
# 9                                       том серии книг
# 12               суверенное государство этого элемента
# 14                                                 NaN
# 16                                                 NaN
# 17   профессия персоны; см. также свойство «область...
# 18                   главная тема работы, произведения
# 19      день, месяц, год, в который субъект был рождён
# 21                                  первое имя персоны
# 22   государство, признающее человека своим граждан...
# 23                              создатель произведения
# 28   наиболее точное место, где субъект родился (на...
# 29            день, месяц, год, в который субъект умер
# 31           высота объекта, измеряемая от уровня воды
# 36   дата, когда организация или объект были основа...
# 37                   фамилия или последнее имя персоны
# 38   дата, когда что-либо происходило или когда утв...
# 39   указывает время начала существования элемента ...
# 40   вид спорта, к которой относится сущность. Для ...
# 42   географическое положение объекта или место соб...
# 43    строка с названием субъекта на официальном языке
# 45   страна происхождения творческого произведения ...
# 46   указание улицы и дома, где физически находится...
# 47   наиболее точное место, где субъект умер (напри...
# 48         учебное заведение, в котором учился человек
# 49   жанр произведения или жанр, в котором работает...
# 51   язык или языки, на которых говорит или пишет п...
# 53   элемент, непосредственно предшествующий данном...
# 54                                                 NaN
# ..                                                 ...
# 639  собрание избираемых представителей, уполномоче...
# 640  чем оборудован описываемый объект (например, т...
# 641  название жителя (жителей) определённой местнос...
# 643  narrative role or character type this characte...
# 644  has part biologically active component. Invers...
# 645        airport that serves as a hub for an airline
# 646  число людей, которые пользуются автобусным мар...
# 647  disease that this pharmaceutical drug, procedu...
# 648    категория водосборного бассейна водного объекта
# 649  лица или партии, включённые в избирательный бю...
# 650  ссылка на эквивалентное имя в том же языке, ко...
# 651   физический объект, с которым есть взаимодействие
# 652  цвет элемента, выраженный шестизначным шестнад...
# 653  протокол взаимодействия для получения доступа ...
# 655  число мест, занимаемых партией, фракцией или г...
# 656  home port of the vessel (if different from "sh...
# 658           звание или должность научного сотрудника
# 660         where the item was located when discovered
# 664  количество зарегистрированных голосующих в это...
# 665  number of people with non-fatal injuries in an...
# 668  сооружение, которое привело к созданию данного...
# 670                              identifier for a drug
# 671  организация, ответственная за публикацию и раз...
# 672    reservoir created upstream of a dam by this dam
# 677                   hand used to play a racket sport
# 679                 работа, созданная на основе данной
# 681  стандартное первое слово в полном наименовании...
# 682                           следствие данной причины
# 683  дата, ассоциируемая с данным личным именем. Кв...
# 684  количество учащихся любого типа в образователь...
#
#                                                aliases        Data type  \
# 3             дата издания, дата премьеры, дата релиза             time
# 6              номер по порядку, позиция, порядок, №ПП           string
# 9                                                  NaN           string
# 12                                              страна    wikibase-item
# 14   АТЕ, вышестоящая административная единица, гор...    wikibase-item
# 16                                                   п    wikibase-item
# 17   деятельность, профессия, ремесло, род деятельн...    wikibase-item
# 18       о, описывает, предмет, про, тема произведения    wikibase-item
# 19                               др, родилась, родился             time
# 21                                                 имя    wikibase-item
# 22                                      национальность    wikibase-item
# 23                                 кто автор, писатель    wikibase-item
# 28                               мр, родилась, родился    wikibase-item
# 29             дс, погиб, смерть настала, умер, умерла             time
# 31                                              высота         quantity
# 36   дата возникновения, время создания, выпуск, го...             time
# 37                                                 NaN    wikibase-item
# 38   время события, год, дата события, день, когда,...             time
# 39   введено с, дата введения, действует с, началос...             time
# 40                                                 NaN    wikibase-item
# 42   местоположение, расположение, в, живёт в, мест...    wikibase-item
# 43                                название официальное  monolingualtext
# 45                                                 NaN    wikibase-item
# 46                                                 NaN           string
# 47                                                  мс    wikibase-item
# 48   альма-матер, аффилиация, ВУЗ, выпускник, закон...    wikibase-item
# 49   жанр кино, жанр оперы, жанр пьесы, литературны...    wikibase-item
# 51     владеет языком, язык выступлений или публикаций    wikibase-item
# 53   prev, предшественник, предыдущее, предыдущее в...    wikibase-item
# 54   next, предшествует, следующее в списке, следую...    wikibase-item
# ..                                                 ...              ...
# 639  ассамблея, дума, конгресс, орган законодательн...    wikibase-item
# 640                                                NaN    wikibase-item
# 641                                            демоним  monolingualtext
# 643                             повествовательная роль    wikibase-item
# 644                                                NaN    wikibase-item
# 645                                                хаб    wikibase-item
# 646                                                NaN         quantity
# 647  используется при болезни, используется при мед...    wikibase-item
# 648                                                NaN    wikibase-item
# 649                                                NaN    wikibase-item
# 650  аналогичное женское имя, аналогичное мужское и...    wikibase-item
# 651                                                 по    wikibase-item
# 652                                                NaN           string
# 653                                                NaN    wikibase-item
# 655              число мест в законодательном собрании         quantity
# 656                                                NaN    wikibase-item
# 658  уз, УЗ, Учёное Звание, доцент, профессор, проф...    wikibase-item
# 660                                                NaN    wikibase-item
# 664                      избиратели, число избирателей         quantity
# 665                                    ранено, раненых         quantity
# 668                                                NaN    wikibase-item
# 670                                                NaN  monolingualtext
# 671                                                NaN    wikibase-item
# 672                                                NaN    wikibase-item
# 677                                                NaN    wikibase-item
# 679                           производное произведение    wikibase-item
# 681                                                NaN    wikibase-item
# 682  =>, влечёт, выливается в, имеет следствие, име...    wikibase-item
# 683                             дата имени, день имени    wikibase-item
# 684  количество студентов, количество учащихся, уча...         quantity
#
#         Count
# 3    24343636
# 6    19970992
# 9    19202486
# 12   10226479
# 14    7271771
# 16    4123711
# 17    3557593
# 18    3346327
# 19    3304427
# 21    2923659
# 22    2884257
# 23    2876412
# 28    2129317
# 29    1677744
# 31    1616420
# 36    1287089
# 37    1239443
# 38    1196303
# 39    1102976
# 40    1042387
# 42     984264
# 43     900061
# 45     855222
# 46     846943
# 47     811221
# 48     793579
# 49     664068
# 51     633594
# 53     596831
# 54     587363
# ..        ...
# 639      2585
# 640      2577
# 641      2568
# 643      2555
# 644      2523
# 645      2518
# 646      2511
# 647      2479
# 648      2470
# 649      2444
# 650      2433
# 651      2403
# 652      2374
# 653      2360
# 655      2334
# 656      2320
# 658      2302
# 660      2275
# 664      2256
# 665      2252
# 668      2232
# 670      2227
# 671      2225
# 672      2225
# 677      2161
# 679      2140
# 681      2119
# 682      2089
# 683      2086
# 684      2079
#
# [500 rows x 7 columns]

# %%
popular_and_good_properties[popular_and_good_properties['description'].isna()]
# Out:
#         ID Goodness                                    label description  \
# 14    P131        1  административно-территориальная единица         NaN
# 16     P21        1                           пол или гендер         NaN
# 54    P156        1                     следующее по порядку         NaN
# 113   P463        1           участник организации или клуба         NaN
# 126  P1350        1                   число сыгранных матчей         NaN
# 146   P101        1                     область деятельности         NaN
# 207   P490        1                    временное обозначение         NaN
# 401  P1923        1                        команда-участница         NaN
#
#                                                aliases      Data type    Count
# 14   АТЕ, вышестоящая административная единица, гор...  wikibase-item  7271771
# 16                                                   п  wikibase-item  4123711
# 54   next, предшествует, следующее в списке, следую...  wikibase-item   587363
# 113  участник, член в, член клуба, член организации...  wikibase-item   173020
# 126                                        игр, матчей       quantity   135780
# 146  направление деятельности, научная сфера, поле ...  wikibase-item    93394
# 207                                                NaN         string    50595
# 401                                                NaN  wikibase-item     8963

# %%
popular_and_good_properties[['ID', 'label', 'Count']].to_csv('top_properties.csv', index=False)

# %%
cnt = 0
for ind, row in popular_and_good_properties.iterrows():
    cnt += 1
    aliases = []
    if str(row['aliases']) != 'nan':
        aliases = row['aliases'].split(', ')
    print(f'# {cnt}.')
    print(f'PID: {row["ID"]}')
    print(f'Label: {row["label"]}')
    print(f'Count: {row["Count"]}')
    print(f'Description: {row["description"]}')
    print('Aliases:')
    for alias in aliases:
          print(alias)
    print('Question forms:\n')
    print('####')
# Out:
# # 1.
# PID: P577
# Label: дата публикации
# Count: 24343636
# Description: дата, когда произведение было выпущено в свет
# Aliases:
# дата издания
# дата премьеры
# дата релиза
# Question forms:
#
# ####
# # 2.
# PID: P1545
# Label: порядковый номер
# Count: 19970992
# Description: позиция элемента в некоторой последовательности, обычно квалификатор
# Aliases:
# номер по порядку
# позиция
# порядок
# №ПП
# Question forms:
#
# ####
# # 3.
# PID: P478
# Label: том
# Count: 19202486
# Description: том серии книг
# Aliases:
# Question forms:
#
# ####
# # 4.
# PID: P17
# Label: государство
# Count: 10226479
# Description: суверенное государство этого элемента
# Aliases:
# страна
# Question forms:
#
# ####
# # 5.
# PID: P131
# Label: административно-территориальная единица
# Count: 7271771
# Description: nan
# Aliases:
# АТЕ
# вышестоящая административная единица
# город
# находится в
# находится в административно-территориальной единице
# регион
# Question forms:
#
# ####
# # 6.
# PID: P21
# Label: пол или гендер
# Count: 4123711
# Description: nan
# Aliases:
# п
# Question forms:
#
# ####
# # 7.
# PID: P106
# Label: род занятий
# Count: 3557593
# Description: профессия персоны; см. также свойство «область деятельности» (Property:P101)
# Aliases:
# деятельность
# профессия
# ремесло
# род деятельности
# Question forms:
#
# ####
# # 8.
# PID: P921
# Label: основная тема
# Count: 3346327
# Description: главная тема работы, произведения
# Aliases:
# о
# описывает
# предмет
# про
# тема произведения
# Question forms:
#
# ####
# # 9.
# PID: P569
# Label: дата рождения
# Count: 3304427
# Description: день, месяц, год, в который субъект был рождён
# Aliases:
# др
# родилась
# родился
# Question forms:
#
# ####
# # 10.
# PID: P735
# Label: личное имя
# Count: 2923659
# Description: первое имя персоны
# Aliases:
# имя
# Question forms:
#
# ####
# # 11.
# PID: P27
# Label: гражданство
# Count: 2884257
# Description: государство, признающее человека своим гражданином
# Aliases:
# национальность
# Question forms:
#
# ####
# # 12.
# PID: P50
# Label: автор
# Count: 2876412
# Description: создатель произведения
# Aliases:
# кто автор
# писатель
# Question forms:
#
# ####
# # 13.
# PID: P19
# Label: место рождения
# Count: 2129317
# Description: наиболее точное место, где субъект родился (например, город, а не страна)
# Aliases:
# мр
# родилась
# родился
# Question forms:
#
# ####
# # 14.
# PID: P570
# Label: дата смерти
# Count: 1677744
# Description: день, месяц, год, в который субъект умер
# Aliases:
# дс
# погиб
# смерть настала
# умер
# умерла
# Question forms:
#
# ####
# # 15.
# PID: P2044
# Label: высота над уровнем моря
# Count: 1616420
# Description: высота объекта, измеряемая от уровня воды
# Aliases:
# высота
# Question forms:
#
# ####
# # 16.
# PID: P571
# Label: дата основания/создания/возникновения
# Count: 1287089
# Description: дата, когда организация или объект были основаны/созданы
# Aliases:
# дата возникновения
# время создания
# выпуск
# год основания
# дата создания
# дата учреждения
# день создания
# запущено
# издано
# написано
# начало
# основан в
# основано в
# пуск
# пущено
# рождение
# сдано в эксплуатацию
# создан в
# создано в
# старт
# учрежден в
# учреждена в
# учреждено в
# Question forms:
#
# ####
# # 17.
# PID: P734
# Label: фамилия
# Count: 1239443
# Description: фамилия или последнее имя персоны
# Aliases:
# Question forms:
#
# ####
# # 18.
# PID: P585
# Label: момент времени
# Count: 1196303
# Description: дата, когда что-либо происходило или когда утверждение было истинным
# Aliases:
# время события
# год
# дата события
# день
# когда
# месяц
# по состоянию на
# точка во времени
# Question forms:
#
# ####
# # 19.
# PID: P580
# Label: дата начала
# Count: 1102976
# Description: указывает время начала существования элемента или время, с которого утверждение приобретает силу
# Aliases:
# введено с
# дата введения
# действует с
# началось в
# применимо с
# сущёствует с
# Question forms:
#
# ####
# # 20.
# PID: P641
# Label: вид спорта
# Count: 1042387
# Description: вид спорта, к которой относится сущность. Для спортивных дисциплин см. Property:P2416
# Aliases:
# Question forms:
#
# ####
# # 21.
# PID: P276
# Label: местонахождение
# Count: 984264
# Description: географическое положение объекта или место события. Используйте P131 в случае административной единицы, P706 — в случае элемента ландшафта, в
# Aliases:
# местоположение
# расположение
# в
# живёт в
# местный падеж
# место события
# находится в
# обитает в
# положение
# происходит в
# размещается в
# Question forms:
#
# ####
# # 22.
# PID: P1448
# Label: официальное название
# Count: 900061
# Description: строка с названием субъекта на официальном языке
# Aliases:
# название официальное
# Question forms:
#
# ####
# # 23.
# PID: P495
# Label: страна происхождения
# Count: 855222
# Description: страна происхождения творческого произведения или другого продукта
# Aliases:
# Question forms:
#
# ####
# # 24.
# PID: P969
# Label: адрес
# Count: 846943
# Description: указание улицы и дома, где физически находится объект
# Aliases:
# Question forms:
#
# ####
# # 25.
# PID: P20
# Label: место смерти
# Count: 811221
# Description: наиболее точное место, где субъект умер (например, город, а не страна)
# Aliases:
# мс
# Question forms:
#
# ####
# # 26.
# PID: P69
# Label: учебное заведение
# Count: 793579
# Description: учебное заведение, в котором учился человек
# Aliases:
# альма-матер
# аффилиация
# ВУЗ
# выпускник
# закончил
# место учёбы
# образование
# окончил
# получил образование в
# университет
# учился в
# Question forms:
#
# ####
# # 27.
# PID: P136
# Label: жанр
# Count: 664068
# Description: жанр произведения или жанр, в котором работает автор
# Aliases:
# жанр кино
# жанр оперы
# жанр пьесы
# литературный жанр
# музыкальный жанр
# Question forms:
#
# ####
# # 28.
# PID: P1412
# Label: языки, на которых говорит или пишет персона
# Count: 633594
# Description: язык или языки, на которых говорит или пишет персона. Может включать родной язык
# Aliases:
# владеет языком
# язык выступлений или публикаций
# Question forms:
#
# ####
# # 29.
# PID: P155
# Label: предыдущее по порядку
# Count: 596831
# Description: элемент, непосредственно предшествующий данному в некоторой череде элементов. Используйте P1365, если предшественник был заменён, т.е. в поли
# Aliases:
# prev
# предшественник
# предыдущее
# предыдущее в списке
# предыдущее по списку
# предыдущий элемент
# следует за
# Question forms:
#
# ####
# # 30.
# PID: P156
# Label: следующее по порядку
# Count: 587363
# Description: nan
# Aliases:
# next
# предшествует
# следующее в списке
# следующее по списку
# следующий элемент
# Question forms:
#
# ####
# # 31.
# PID: P1810
# Label: при создании назван как
# Count: 552146
# Description: указанное в титрах имя человека, участвовавшего в создании произведения, если отличается от реального имени
# Aliases:
# в титрах как
# обозначен как
# указан как
# Question forms:
#
# ####
# # 32.
# PID: P582
# Label: дата окончания
# Count: 534129
# Description: указывает время прекращения существования элемента или время, с которого утверждение утрачивает силу
# Aliases:
# дата завершения
# дата закрытия
# дата конца
# действовало до
# закончилось в
# конец в
# применимо до
# Question forms:
#
# ####
# # 33.
# PID: P527
# Label: состоит из
# Count: 458745
# Description: объект, являющийся частью данного субъекта
# Aliases:
# включает в себя
# включает компонент
# включает компоненты
# включает части
# из
# имеет дополнение
# имеет компоненты
# имеет части
# имеет частью
# компоненты
# содержит
# составляющие
# части
# Question forms:
#
# ####
# # 34.
# PID: P170
# Label: создатель
# Count: 442995
# Description: создатель творческого произведения и т. п. (для случаев, когда нет более точного свойства)
# Aliases:
# создатель объекта
# создатель произведения
# Question forms:
#
# ####
# # 35.
# PID: P195
# Label: хранится в коллекции
# Count: 441380
# Description: художественная галерея, музей, библиотека или архив, где хранится этот объект
# Aliases:
# Question forms:
#
# ####
# # 36.
# PID: P39
# Label: занимаемая должность
# Count: 426510
# Description: текущая или прошлая политическая должность
# Aliases:
# должность
# работает в должности
# Question forms:
#
# ####
# # 37.
# PID: P2048
# Label: высота/рост
# Count: 413555
# Description: высота объекта
# Aliases:
# высота над землёй
# высота над поверхностью
# рост
# Question forms:
#
# ####
# # 38.
# PID: P1082
# Label: численность населения
# Count: 392690
# Description: количество людей, населяющих место
# Aliases:
# жителей
# население
# Question forms:
#
# ####
# # 39.
# PID: P186
# Label: сделано из
# Count: 391991
# Description: материал, из которого сделан объект
# Aliases:
# материал
# сделан из
# сделана из
# сделаны из
# Question forms:
#
# ####
# # 40.
# PID: P166
# Label: полученные награды
# Count: 375958
# Description: награды, полученные персоной, организацией или произведением
# Aliases:
# н
# звания
# медали
# награды
# ордена
# почётные звания
# премии
# титулы
# Question forms:
#
# ####
# # 41.
# PID: P2046
# Label: площадь
# Count: 367746
# Description: численная характеристика двумерной геометрической фигуры
# Aliases:
# Question forms:
#
# ####
# # 42.
# PID: P54
# Label: член спортивной команды
# Count: 358928
# Description: команда, в которой данный человек участвует/участвовал
# Aliases:
# клуб
# команда
# спортивная команда
# спортивный клуб
# член спортивного клуба
# Question forms:
#
# ####
# # 43.
# PID: P1264
# Label: действительно для периода
# Count: 345433
# Description: период времени, для которого утверждение корректно
# Aliases:
# Question forms:
#
# ####
# # 44.
# PID: P1705
# Label: название на языке оригинала
# Count: 339430
# Description: наименование на официальном языке (P37) или на языке оригинала (P364)
# Aliases:
# на официальном языке
# оригинальное название
# Question forms:
#
# ####
# # 45.
# PID: P102
# Label: член политической партии
# Count: 300350
# Description: политическая партия, членом которой является (или являлась) данная персона
# Aliases:
# партия
# политическая партия
# член партии
# Question forms:
#
# ####
# # 46.
# PID: P413
# Label: позиция в команде
# Count: 297812
# Description: позиция, на которой обычно выступает игрок, или роль, которую он обычно выполняет
# Aliases:
# амплуа игрока
# роль в команде
# Question forms:
#
# ####
# # 47.
# PID: P175
# Label: исполнитель/артист
# Count: 295748
# Description: performer involved in the performance or the recording of a musical work
# Aliases:
# группа (музыкальная)
# музыкальная группа
# музыкант
# Question forms:
#
# ####
# # 48.
# PID: P1559
# Label: имя на родном языке
# Count: 294166
# Description: текущее имя персоны на её родном языке
# Aliases:
# имя при рождении
# на родном языке
# оригинал имени
# оригинальное имя
# Question forms:
#
# ####
# # 49.
# PID: P2049
# Label: ширина
# Count: 290239
# Description: ширина объекта
# Aliases:
# Question forms:
#
# ####
# # 50.
# PID: P123
# Label: издатель
# Count: 289210
# Description: название организации, ответственной за публикацию объекта
# Aliases:
# издательство
# Question forms:
#
# ####
# # 51.
# PID: P518
# Label: указано для части
# Count: 279633
# Description: часть элемента, для которой действует данное заявление (например, координаты указаны для столицы или центра страны)
# Aliases:
# истинно для определённой части страны
# координаты введены для указанной части
# относится к части
# указана определённая часть
# это заявление указано для части
# Question forms:
#
# ####
# # 52.
# PID: P108
# Label: работодатель
# Count: 276038
# Description: организация, в которой субъект работает или работал
# Aliases:
# место работы
# работает на
# служит
# сотрудник
# Question forms:
#
# ####
# # 53.
# PID: P364
# Label: язык оригинала
# Count: 273310
# Description: язык, на котором первоначально был создан фильм или произведение (для письменных произведений используйте P407 «язык произведения или назва
# Aliases:
# язык фильма
# языки фильма
# Question forms:
#
# ####
# # 54.
# PID: P3452
# Label: вывод из
# Count: 270192
# Description: утверждение добавлено на основе завления в следующем элементе
# Aliases:
# выведено из
# догадка из
# заключение из
# предположение из
# Question forms:
#
# ####
# # 55.
# PID: P2067
# Label: масса
# Count: 267231
# Description: масса/вес объекта
# Aliases:
# вес
# водоизмещение
# молярная масса
# Question forms:
#
# ####
# # 56.
# PID: P282
# Label: письменность
# Count: 259445
# Description: письменность, используемая языком
# Aliases:
# азбука
# алфавит
# письмо
# Question forms:
#
# ####
# # 57.
# PID: P887
# Label: на основе эвристики
# Count: 253870
# Description: indicates that the property value is determined based on some heuristic (Q201413); to be used as source
# Aliases:
# Question forms:
#
# ####
# # 58.
# PID: P57
# Label: режиссёр
# Count: 226415
# Description: режиссёр фильма
# Aliases:
# кинорежиссер
# кинорежиссёр
# режиссер
# Question forms:
#
# ####
# # 59.
# PID: P642
# Label: относится к
# Count: 223241
# Description: квалификатор, ограничивающий (уточняющий) утверждение только определённой сферой, географической территорией
# Aliases:
# аллатив
# введённое выше значение применимо только к
# винительный падеж
# дательный падеж
# для
# до
# к
# ко
# область применимости
# относится к
# падеж приближения
# по направлению к
# применимо к
# прямое дополнение
# ради
# родительный падеж
# с
# со
# чтобы
# этого
# Question forms:
#
# ####
# # 60.
# PID: P159
# Label: расположение штаб-квартиры
# Count: 206350
# Description: определенное место, где располагается штаб-квартира организации
# Aliases:
# штаб-квартира расположена
# Question forms:
#
# ####
# # 61.
# PID: P264
# Label: лейбл звукозаписи
# Count: 202702
# Description: brand and trademark associated with the marketing of subject music recordings and music videos
# Aliases:
# лейбл
# музыкальный лейбл
# Question forms:
#
# ####
# # 62.
# PID: P937
# Label: место активности
# Count: 195905
# Description: место деятельности субъекта
# Aliases:
# в
# действует в
# место деятельности:
# место работы:
# работает в
# Question forms:
#
# ####
# # 63.
# PID: P1344
# Label: участвовал в
# Count: 185631
# Description: мероприятие, в котором участвовала персона или организация, противоположно P710 и P1923
# Aliases:
# принял(а) участие в
# участвовала в
# Question forms:
#
# ####
# # 64.
# PID: P161
# Label: в ролях
# Count: 175787
# Description: актёры данного произведения; используйте квалификаторы для разделения главных и второстепенных ролей
# Aliases:
# актер
# актеры
# актриса
# актёр
# актёры
# Question forms:
#
# ####
# # 65.
# PID: P463
# Label: участник организации или клуба
# Count: 173020
# Description: nan
# Aliases:
# участник
# член в
# член клуба
# член организации
# членствует в
# является одним из членов в
# Question forms:
#
# ####
# # 66.
# PID: P138
# Label: названо в честь
# Count: 166838
# Description: объект, персона или событие, чьё имя/название послужило основой для данного элемента
# Aliases:
# в честь
# имени
# назван в честь
# названа в честь
# носит имя
# эпоним
# Question forms:
#
# ####
# # 67.
# PID: P140
# Label: отношение к религии
# Count: 164697
# Description: ДОЛЖНО быть утверждено самим субъектом или подтверждено историческими источниками
# Aliases:
# вероисповедание
# конфессиональная принадлежность
# отношение к религии
# религия
# Question forms:
#
# ####
# # 68.
# PID: P274
# Label: химическая формула
# Count: 152120
# Description: описание молекулы, составленное из знаков химических элементов
# Aliases:
# Question forms:
#
# ####
# # 69.
# PID: P127
# Label: владельцем является
# Count: 149180
# Description: владелец этой сущности
# Aliases:
# владелец
# им владеет
# принадлежит
# это принадлежит
# Question forms:
#
# ####
# # 70.
# PID: P1351
# Label: число забитых голов/набранных очков
# Count: 146066
# Description: количество забитых голов или набранных очков в матче или турнире. Для очков, подсчитанных по количеству побед-ничей-поражений в лиге, испол
# Aliases:
# голов
# забито
# забитые голы
# набранных очков
# набрано
# Question forms:
#
# ####
# # 71.
# PID: P2043
# Label: длина
# Count: 144408
# Description: линейное измерение объекта
# Aliases:
# протяжённость
# расстояние
# Question forms:
#
# ####
# # 72.
# PID: P22
# Label: отец
# Count: 142326
# Description: отец персоны
# Aliases:
# батько
# батя
# кто отец
# папа
# родитель
# Question forms:
#
# ####
# # 73.
# PID: P462
# Label: цвет
# Count: 140588
# Description: цвет субъекта
# Aliases:
# Question forms:
#
# ####
# # 74.
# PID: P119
# Label: место погребения
# Count: 138028
# Description: элемент, описывающий местность гробницы, упокоения и т.п.
# Aliases:
# мз
# мп
# гроб
# гробница
# захоронен
# кладбище
# место захоронения
# могила
# погребён
# похоронен
# похоронена
# Question forms:
#
# ####
# # 75.
# PID: P1350
# Label: число сыгранных матчей
# Count: 135780
# Description: nan
# Aliases:
# игр
# матчей
# Question forms:
#
# ####
# # 76.
# PID: P607
# Label: война/сражение
# Count: 135258
# Description: войны или сражения, в которых участвовала данная личность или объект
# Aliases:
# битва
# война
# конфликт
# сражение
# Question forms:
#
# ####
# # 77.
# PID: P2868
# Label: в качестве
# Count: 134785
# Description: роль предмета в некотором контексте. Для актёров существует отдельное свойство P453
# Aliases:
# в роли
# выполняет функцию
# играет роль
# служит как
# Question forms:
#
# ####
# # 78.
# PID: P1843
# Label: народное название таксона
# Count: 133927
# Description: просторечное название биологического таксона
# Aliases:
# название народное
# обиходное название
# обычное название
# просторечное название
# разговорное название
# Question forms:
#
# ####
# # 79.
# PID: P86
# Label: композитор
# Count: 125329
# Description: автор музыкального произведения
# Aliases:
# Question forms:
#
# ####
# # 80.
# PID: P2348
# Label: эра
# Count: 117854
# Description: исторический период [review translation!]
# Aliases:
# исторический период
# эпоха
# Question forms:
#
# ####
# # 81.
# PID: P137
# Label: обслуживающее лицо
# Count: 117771
# Description: у оборудования, учреждения либо услуги
# Aliases:
# администратор
# заведующий
# обслуживается
# обслуживающая компания
# оператор
# Question forms:
#
# ####
# # 82.
# PID: P1532
# Label: представляет страну в спорте
# Count: 115344
# Description: страна, которую представляет или имеет право представлять человек на международных спортивных соревнованиях
# Aliases:
# выступает за страну
# гражданство для спорта
# представляет страну
# спортивное гражданство
# страна для спорта
# Question forms:
#
# ####
# # 83.
# PID: P40
# Label: дети
# Count: 114142
# Description: дети этого человека
# Aliases:
# дети
# дитя
# дочь
# ребенок
# ребёнок
# сын
# Question forms:
#
# ####
# # 84.
# PID: P47
# Label: имеет границы с
# Count: 112329
# Description: страны или административные единицы одинакового уровня, с которыми этот элемент граничит по суше или воде
# Aliases:
# граничит с
# Question forms:
#
# ####
# # 85.
# PID: P58
# Label: сценарист
# Count: 108506
# Description: автор(ы) сценария фильма
# Aliases:
# автор сценария
# сценаристы
# Question forms:
#
# ####
# # 86.
# PID: P179
# Label: является частью цикла
# Count: 105807
# Description: ряд или последовательность, в которой состоит данный элемент
# Aliases:
# серия
# цикл
# часть серии
# часть цикла
# является частью серии
# Question forms:
#
# ####
# # 87.
# PID: P26
# Label: супруг(а)
# Count: 103255
# Description: супруг или супруга персоны
# Aliases:
# брак с
# в браке с
# жена
# муж
# семья с
# супруг
# супруга
# Question forms:
#
# ####
# # 88.
# PID: P2094
# Label: квалифицирован для
# Count: 101491
# Description: official classification by a regulating body under which the subject (events, teams, participants, or equipment) qualifies for inclusion
# Aliases:
# квалифицирован на
# квалифицирована для
# квалифицировано для
# Question forms:
#
# ####
# # 89.
# PID: P291
# Label: место публикации
# Count: 95509
# Description: географическое место публикации (для произведений - первого издания)
# Aliases:
# Question forms:
#
# ####
# # 90.
# PID: P3373
# Label: брат/сестра
# Count: 95326
# Description: брат или сестра данной персоны
# Aliases:
# брат
# сестра
# сиблинг
# Question forms:
#
# ####
# # 91.
# PID: P101
# Label: область деятельности
# Count: 93394
# Description: nan
# Aliases:
# направление деятельности
# научная сфера
# поле деятельности
# соответствует деятельности
# сфера работы
# Question forms:
#
# ####
# # 92.
# PID: P180
# Label: изображённый объект
# Count: 90090
# Description: изображённая персона, место, объект или событие
# Aliases:
# изображает
# изображенный объект
# изображено
# описываемый объект
# описывает
# Question forms:
#
# ####
# # 93.
# PID: P2047
# Label: продолжительность
# Count: 89855
# Description: продолжительность по времени
# Aliases:
# время
# длительность
# Question forms:
#
# ####
# # 94.
# PID: P162
# Label: продюсер
# Count: 89082
# Description: person(s) who produced the film, musical work, theatrical production, etc. (for film, this does not include executive producers, associate producers, etc.) [for production company, use P272, video games - use P178]
# Aliases:
# Question forms:
#
# ####
# # 95.
# PID: P509
# Label: причина смерти
# Count: 85410
# Description: элемент с описанием причины смерти персоны или организма. Например: лейкемия, автокатастрофа
# Aliases:
# метод убийства
# Question forms:
#
# ####
# # 96.
# PID: P512
# Label: учёная степень
# Count: 84028
# Description: учёная степень персоны
# Aliases:
# степень
# академическая степень
# научная степень
# ус
# ученая степень
# учёная степень
# Question forms:
#
# ####
# # 97.
# PID: P3744
# Label: число подписчиков
# Count: 83449
# Description: number of subscribers for subscription based companies, e.g. telecommunication companies, newspapers, pay-TV channels, etc.
# Aliases:
# подписчиков
# Question forms:
#
# ####
# # 98.
# PID: P1619
# Label: дата официального открытия
# Count: 82478
# Description: date or point in time an event, museum, theater etc. officially opened
# Aliases:
# дата открытия
# Question forms:
#
# ####
# # 99.
# PID: P1539
# Label: женское население
# Count: 81278
# Description: количество проживающих женщин
# Aliases:
# Question forms:
#
# ####
# # 100.
# PID: P576
# Label: дата прекращения существования
# Count: 81075
# Description: дата, когда сущность перестала существовать
# Aliases:
# вымирание
# дата вымирания
# дата закрытия
# дата окончания работы
# дата реорганизации
# дата уничтожения
# дата упразднения
# закрылась в
# ликвидировано в
# окончание работы
# организация закрыта
# прекратила существование в
# распалось в
# расторгнут в
# реорганизован
# роспуск
# уничтожено в
# упразднена в
# Question forms:
#
# ####
# # 101.
# PID: P1104
# Label: количество страниц
# Count: 80888
# Description: количество страниц в работе
# Aliases:
# страниц
# число страниц
# Question forms:
#
# ####
# # 102.
# PID: P1540
# Label: мужское население
# Count: 80700
# Description: количество только мужчин
# Aliases:
# мужчин
# Question forms:
#
# ####
# # 103.
# PID: P566
# Label: базионим
# Count: 78993
# Description: the legitimate, previously published name on which a new combination or name at new rank is based
# Aliases:
# базоним
# Question forms:
#
# ####
# # 104.
# PID: P972
# Label: каталог
# Count: 78548
# Description: каталог элемента в основном значении или квалификатор для использования с каталожными кодами (P528)
# Aliases:
# Question forms:
#
# ####
# # 105.
# PID: P103
# Label: родной язык
# Count: 78105
# Description: язык, который персона знает с рождения
# Aliases:
# говорит на языке
# язык
# Question forms:
#
# ####
# # 106.
# PID: P395
# Label: код автомобильного номера
# Count: 77701
# Description: символьный код для автомобильных номеров
# Aliases:
# автомобильный код
# код автомобильного номера
# код региона
# Question forms:
#
# ####
# # 107.
# PID: P36
# Label: столица
# Count: 77596
# Description: центральный населённый пункт в административной единице
# Aliases:
# административный центр
# главный город
# Question forms:
#
# ####
# # 108.
# PID: P150
# Label: административно делится на
# Count: 77479
# Description: единицы, на которые непосредственно подразделяется данная административная единица
# Aliases:
# нижестоящие административные единицы
# Question forms:
#
# ####
# # 109.
# PID: P403
# Label: впадает в
# Count: 75504
# Description: гидрологический объект, в который впадает водоток (река, ручей)
# Aliases:
# приток
# устье водотока
# является притоком
# Question forms:
#
# ####
# # 110.
# PID: P1303
# Label: музыкальный инструмент
# Count: 75364
# Description: музыкальный инструмент, на котором играл/играет человек
# Aliases:
# играет на
# играл на
# инструмент
# Question forms:
#
# ####
# # 111.
# PID: P669
# Label: расположен на улице
# Count: 74327
# Description: улица или дорога, на которой расположен элемент; часть адреса
# Aliases:
# адрес
# на улице
# находится на улице
# улица
# Question forms:
#
# ####
# # 112.
# PID: P749
# Label: материнская компания (организация, учреждение)
# Count: 72593
# Description: родительская компания (организация, учреждение), противоположность дочерним компаниям (организациям, учреждениям) (P355)
# Aliases:
# родительская компания
# холдинг
# Question forms:
#
# ####
# # 113.
# PID: P1001
# Label: юрисдикция распространяется на
# Count: 70403
# Description: территория, на которую распространяется юрисдикция сущности, описываемой в данном элементе
# Aliases:
# Question forms:
#
# ####
# # 114.
# PID: P1196
# Label: род смерти
# Count: 70084
# Description: термин в судебной медицине
# Aliases:
# Question forms:
#
# ####
# # 115.
# PID: P1454
# Label: организационно-правовая форма
# Count: 69659
# Description: legal form of an organization
# Aliases:
# Question forms:
#
# ####
# # 116.
# PID: P768
# Label: избирательный округ
# Count: 68834
# Description: избирательный округ, который представляет персона в парламенте
# Aliases:
# округ
# электоральный округ
# Question forms:
#
# ####
# # 117.
# PID: P1538
# Label: число домохозяйств
# Count: 68366
# Description: total number of households in this place, includes dwellings of all types
# Aliases:
# Question forms:
#
# ####
# # 118.
# PID: P551
# Label: место жительства
# Count: 66352
# Description: место, где человек живёт или жил
# Aliases:
# адрес
# живёт в
# жил в
# место проживания
# Question forms:
#
# ####
# # 119.
# PID: P344
# Label: кинооператор
# Count: 66299
# Description: кинематографическая профессия, ответственный за съёмку, освещение и фильтрацию
# Aliases:
# оператор (кино)
# Question forms:
#
# ####
# # 120.
# PID: P241
# Label: вид или род войск
# Count: 66126
# Description: вид или род войск, к которому относится награда, воинское формирование или военнослужащий
# Aliases:
# войска
# род войск
# Question forms:
#
# ####
# # 121.
# PID: P61
# Label: первооткрыватель или изобретатель
# Count: 66044
# Description: кем открыт или изобретён этот элемент
# Aliases:
# изобретатель
# первооткрыватель
# Question forms:
#
# ####
# # 122.
# PID: P1376
# Label: является столицей
# Count: 65627
# Description: страна, штат, регион или другая административно-территориальная единица, столицей которой является данный город (муниципалитет)
# Aliases:
# столица
# центр
# Question forms:
#
# ####
# # 123.
# PID: P1477
# Label: имя при рождении
# Count: 64584
# Description: если отличается от текущего имени
# Aliases:
# Question forms:
#
# ####
# # 124.
# PID: P2817
# Label: входит в состав списка памятников культурного наследия
# Count: 64396
# Description: памятник входит в состав списка памятников культурного наследия
# Aliases:
# Question forms:
#
# ####
# # 125.
# PID: P410
# Label: воинское звание
# Count: 64146
# Description: воинское звание, до которого дослужился человек
# Aliases:
# звание
# Question forms:
#
# ####
# # 126.
# PID: P575
# Label: дата открытия
# Count: 62991
# Description: дата, когда объект был открыт (обнаружен)
# Aliases:
# дата изобретения
# дата обнаружения
# изобретено в
# обнаружено в
# открыто в
# Question forms:
#
# ####
# # 127.
# PID: P172
# Label: этническая группа
# Count: 62250
# Description: ДОЛЖНО быть утверждено самим субъектом или подтверждено консенсусом учёных (либо, для вымышленных персонажей, текстом произведения)
# Aliases:
# етнос
# культура
# национальность
# Question forms:
#
# ####
# # 128.
# PID: P750
# Label: компания-распространитель
# Count: 61359
# Description: распространитель работы
# Aliases:
# дистибутор
# дистрибьютор
# кем распространяется
# компания-дистибутор
# компания-дистрибьютор
# кто распространяет
# распространитель
# Question forms:
#
# ####
# # 129.
# PID: P859
# Label: спонсор
# Count: 60627
# Description: лицо, спонсирующее данный элемент
# Aliases:
# Question forms:
#
# ####
# # 130.
# PID: P460
# Label: предположительно одно и то же с
# Count: 60557
# Description: есть мнение, что этот элемент — то же самое, что и тот элемент, но это утверждение оспаривается
# Aliases:
# вероятно
# одно и то же с
# возможно одно и то же с
# одно и то же
# синоним
# то же самое
# Question forms:
#
# ####
# # 131.
# PID: P793
# Label: ключевое событие
# Count: 60035
# Description: событие, важное для этого элемента
# Aliases:
# важное событие
# веха
# главное событие
# значимое событие
# основное событие
# событие
# Question forms:
#
# ####
# # 132.
# PID: P1366
# Label: заменён на
# Count: 59746
# Description: человек, организация или объект, который занял место другого в должности, позиции и т. д. Используйте P156 («следующее по порядку») если объект
# Aliases:
# заменен
# заменена кем
# заменена на
# заменён
# заменён кем
# кем заменён
# преемник
# преемником в должности стал
# продолжатель
# следующим в должности стал
# чем заменён
# Question forms:
#
# ####
# # 133.
# PID: P5138
# Label: сезон клуба или команды
# Count: 59709
# Description: club or team that played the season
# Aliases:
# Question forms:
#
# ####
# # 134.
# PID: P149
# Label: архитектурный стиль
# Count: 57441
# Description: направление в архитектуре, которому следовали строители здания
# Aliases:
# Question forms:
#
# ####
# # 135.
# PID: P272
# Label: производящая компания
# Count: 56987
# Description: компания, производящая фильм, музыку или театральную постановку
# Aliases:
# кинокомпания
# киностудия
# производящая студия
# студия
# Question forms:
#
# ####
# # 136.
# PID: P708
# Label: епархия
# Count: 55690
# Description: administrative division of the church to which the element belongs
# Aliases:
# диоцез
# Question forms:
#
# ####
# # 137.
# PID: P1365
# Label: заменил
# Count: 55179
# Description: человек, организация или объект, который был заменён в должности, позиции и т.д. Используйте P155 ("предыдущее по порядку"), если предыдущий объ
# Aliases:
# заменил кого
# заменила
# кого заменил:
# предшественником в должности был
# сменил
# сменила
# что заменил:
# Question forms:
#
# ####
# # 138.
# PID: P176
# Label: производитель
# Count: 54712
# Description: основной производитель (без субподрядчиков)
# Aliases:
# изготовитель
# разработчик
# сборка
# Question forms:
#
# ####
# # 139.
# PID: P81
# Label: железнодорожная линия
# Count: 54594
# Description: железнодорожная линия, с которой связан этот элемент
# Aliases:
# Question forms:
#
# ####
# # 140.
# PID: P1114
# Label: число объектов
# Count: 53746
# Description: сколько существует подобных объектов
# Aliases:
# всего
# количество
# число подобных объектов
# Question forms:
#
# ####
# # 141.
# PID: P449
# Label: первоначальная телесеть
# Count: 53644
# Description: радио или телевизионная сеть, которая впервые транслировала сериал, передачу
# Aliases:
# первоначальный телеканал
# телеканал
# телесеть
# Question forms:
#
# ####
# # 142.
# PID: P65
# Label: место астрономического открытия
# Count: 51679
# Description: the place where an astronomical object was discovered (observatory, satellite)
# Aliases:
# Question forms:
#
# ####
# # 143.
# PID: P490
# Label: временное обозначение
# Count: 50595
# Description: nan
# Aliases:
# Question forms:
#
# ####
# # 144.
# PID: P197
# Label: соседняя станция
# Count: 50529
# Description: связь между железнодорожными станциями
# Aliases:
# предыдущая станция
# следующая станция
# Question forms:
#
# ####
# # 145.
# PID: P393
# Label: номер издания
# Count: 50366
# Description: число, определяющее порядок издания
# Aliases:
# издание
# номер редакции
# редакция
# Question forms:
#
# ####
# # 146.
# PID: P2937
# Label: срок полномочий парламента
# Count: 50102
# Description: term of a parliament or any deliberative assembly
# Aliases:
# период действия полномочий
# Question forms:
#
# ####
# # 147.
# PID: P3450
# Label: сезон чего
# Count: 49733
# Description: property that shows the competition of which the item is a season. Use P5138 for "season of club or team".
# Aliases:
# спортивный сезон
# Question forms:
#
# ####
# # 148.
# PID: P30
# Label: часть света
# Count: 46003
# Description: часть света, в которой находится элемент. Используется для стран
# Aliases:
# континент
# Question forms:
#
# ####
# # 149.
# PID: P4614
# Label: водосбор
# Count: 44300
# Description: водосборный бассейн
# Aliases:
# водосборный бассейн
# речной бассейн
# Question forms:
#
# ####
# # 150.
# PID: P1113
# Label: количество серий или эпизодов
# Count: 43932
# Description: число серий в многосерийном фильме, сериале и т. п.
# Aliases:
# количество эпизодов
# число серий
# Question forms:
#
# ####
# # 151.
# PID: P25
# Label: мать
# Count: 43923
# Description: мать персоны
# Aliases:
# мама
# родители
# Question forms:
#
# ####
# # 152.
# PID: P135
# Label: художественное направление
# Count: 42931
# Description: литературное, художественное или философское направление, связанное с этой персоной или произведением
# Aliases:
# движение
# Question forms:
#
# ####
# # 153.
# PID: P4552
# Label: горный хребет
# Count: 42172
# Description: range or subrange to which the geographical item belongs
# Aliases:
# горная цепь
# Question forms:
#
# ####
# # 154.
# PID: P945
# Label: лояльность
# Count: 42130
# Description: кому (чему) данная страна, человек или организация служит
# Aliases:
# принадлежность
# Question forms:
#
# ####
# # 155.
# PID: P2715
# Label: выбран по результатам
# Count: 41234
# Description: ссылка на выборы, по результатам которых была выбрана персоналия
# Aliases:
# выбран на
# Question forms:
#
# ####
# # 156.
# PID: P1441
# Label: представлено в работе
# Count: 40635
# Description: произведение, в котором появляется вымышленный элемент
# Aliases:
# из художественного произведения
# Question forms:
#
# ####
# # 157.
# PID: P126
# Label: ответственность несёт
# Count: 40399
# Description: организация, ответственная за функционирование объекта
# Aliases:
# обслуживается
# ответственное лицо
# поддерживается
# Question forms:
#
# ####
# # 158.
# PID: P2547
# Label: периметр
# Count: 39979
# Description: длина замкнутого контура
# Aliases:
# Question forms:
#
# ####
# # 159.
# PID: P59
# Label: созвездие
# Count: 39811
# Description: участок на небесной сфере для удобства ориентирования на звёздном небе
# Aliases:
# Question forms:
#
# ####
# # 160.
# PID: P1642
# Label: сделка по приобретению
# Count: 39506
# Description: как игрок был приобретён, квалификатор для P54 (член спортивной команды)
# Aliases:
# Question forms:
#
# ####
# # 161.
# PID: P4908
# Label: сезон
# Count: 38437
# Description: в какой сезон телесериала входит серия телесериала
# Aliases:
# входит в сезон
# часть сезона
# является частью сезона
# Question forms:
#
# ####
# # 162.
# PID: P16
# Label: система автомагистралей
# Count: 38122
# Description: system (or specific country specific road type) of which the highway is a part
# Aliases:
# дорожная система
# сеть автодорог
# Question forms:
#
# ####
# # 163.
# PID: P366
# Label: используется как/для/в
# Count: 37998
# Description: основное назначение объекта (включая текущее и прошлое использование)
# Aliases:
# для
# использование
# используется в качестве
# используется для
# используется как средство для
# используется как
# для
# как
# назначение
# применение
# применяется для
# Question forms:
#
# ####
# # 164.
# PID: P84
# Label: архитектор
# Count: 37773
# Description: человек или компания, разработавшая проект этого здания
# Aliases:
# Question forms:
#
# ####
# # 165.
# PID: P1269
# Label: тематически относится к
# Count: 37733
# Description: тема, у который данный элемент — один из аспектов; элемент, предоставлющий более общую информацию по той же тематике
# Aliases:
# аспект от
# главная тема
# общая тема
# основная тема
# подтема
# подэлемент от
# субэлемент от
# часть более общей темы
# часть от более общей темы
# часть темы
# Question forms:
#
# ####
# # 166.
# PID: P3831
# Label: значение выступает в роли
# Count: 36930
# Description: значение выступает в роли (в контексте утверждения)
# Aliases:
# в качестве
# в роли
# объект выступает в роли
# роль в рамках утверждения
# Question forms:
#
# ####
# # 167.
# PID: P1352
# Label: спортивный рейтинг
# Count: 36342
# Description: место, занятое командой или спортсменом в спортивном турнире или состязании
# Aliases:
# занятое место
# место в рейтинге
# место в таблице
# Question forms:
#
# ####
# # 168.
# PID: P3740
# Label: число работ
# Count: 36004
# Description: qualifier on identifiers, eg for creators or locations, giving the number of works in the external database associated with the subject of the identifier
# Aliases:
# Question forms:
#
# ####
# # 169.
# PID: P1346
# Label: победитель
# Count: 34881
# Description: победитель соревнования
# Aliases:
# победительница
# Question forms:
#
# ####
# # 170.
# PID: P275
# Label: лицензия
# Count: 34368
# Description: лицензия, под которой опубликовано произведение
# Aliases:
# Question forms:
#
# ####
# # 171.
# PID: P670
# Label: номер дома
# Count: 34330
# Description: используется для уточнения P669
# Aliases:
# адрес
# дом номер
# корпус
# номер по улице
# строение
# Question forms:
#
# ####
# # 172.
# PID: P1534
# Label: конечный результат
# Count: 34246
# Description: квалификатор свойства "дата окончания"
# Aliases:
# результат
# итог
# Question forms:
#
# ####
# # 173.
# PID: P118
# Label: играет в лиге
# Count: 34220
# Description: спортивная лига, в которой выступает или выступала команда
# Aliases:
# Question forms:
#
# ####
# # 174.
# PID: P1040
# Label: монтажёр
# Count: 33122
# Description: человек, который работает с плёнкой (записью), выбирая нужные кадры/последовательности
# Aliases:
# монтажер
# редактор фильма
# Question forms:
#
# ####
# # 175.
# PID: P97
# Label: титул
# Count: 32952
# Description: дворянский титул персоны
# Aliases:
# дворянский титул
# Question forms:
#
# ####
# # 176.
# PID: P710
# Label: участник(и)
# Count: 32005
# Description: человек, группа людей или организация, принимавшая участие в событии
# Aliases:
# участники
# Question forms:
#
# ####
# # 177.
# PID: P1319
# Label: не ранее
# Count: 31938
# Description: самая ранняя дата, когда событие могло произойти
# Aliases:
# не раньше
# после
# самое раннее
# Question forms:
#
# ####
# # 178.
# PID: P400
# Label: платформа
# Count: 30587
# Description: платформа, для которой было разработано программное обеспечение
# Aliases:
# Question forms:
#
# ####
# # 179.
# PID: P53
# Label: род
# Count: 30373
# Description: династия или семья благородного происхождения, членом которой является этот человек
# Aliases:
# дворянский род
# династия
# семья благородного происхождения
# Question forms:
#
# ####
# # 180.
# PID: P2061
# Label: соотношение сторон
# Count: 30371
# Description: ширина к высоте
# Aliases:
# Question forms:
#
# ####
# # 181.
# PID: P1326
# Label: не позднее
# Count: 30333
# Description: наиболее поздняя дата, когда событие могло случиться
# Aliases:
# не позже
# самое позднее
# Question forms:
#
# ####
# # 182.
# PID: P2437
# Label: число сезонов
# Count: 29819
# Description: количество независимых групп эпизодов телесериала
# Aliases:
# количество сезонов
# Question forms:
#
# ####
# # 183.
# PID: P178
# Label: разработчик
# Count: 28993
# Description: организация или человек, разработавший предмет
# Aliases:
# Question forms:
#
# ####
# # 184.
# PID: P206
# Label: находится на берегу водоёма
# Count: 28883
# Description: водоём (озеро или река), на берегу которого находится НП
# Aliases:
# река
# озеро
# водоём
# водоем
# лежит на
# на берегу
# стоит на
# Question forms:
#
# ####
# # 185.
# PID: P740
# Label: место создания
# Count: 28835
# Description: location where a group or organization was formed
# Aliases:
# место формирования
# Question forms:
#
# ####
# # 186.
# PID: P1853
# Label: группа крови
# Count: 28401
# Description: тип группы крови человека или организма
# Aliases:
# Question forms:
#
# ####
# # 187.
# PID: P1191
# Label: первое исполнение
# Count: 28228
# Description: дата первого исполнения произведения
# Aliases:
# дата первого релиза
# дата первой постановки
# первая постановка
# премьера
# Question forms:
#
# ####
# # 188.
# PID: P452
# Label: отрасль
# Count: 28066
# Description: сфера деятельности компании или организации
# Aliases:
# индустрия
# Question forms:
#
# ####
# # 189.
# PID: P112
# Label: основатель
# Count: 27763
# Description: основатель или сооснователь организации, учения или населённого пункта
# Aliases:
# учредитель
# Question forms:
#
# ####
# # 190.
# PID: P840
# Label: история происходит в месте
# Count: 27558
# Description: сюжет данного произведения происходит в данном местоположении
# Aliases:
# действие происходит в месте
# место действия
# Question forms:
#
# ####
# # 191.
# PID: P4100
# Label: парламентская группа
# Count: 26989
# Description: parliamentary group which a member of a parliament belongs to
# Aliases:
# Question forms:
#
# ####
# # 192.
# PID: P800
# Label: выдающееся произведение
# Count: 26191
# Description: выдающаяся научная работа или произведение искусства
# Aliases:
# notable work
# Opus Magna
# известное произведение
# опус магна
# произведение
# работа
# сочинения
# шедевр
# Question forms:
#
# ####
# # 193.
# PID: P1268
# Label: представляет
# Count: 25631
# Description: organization or individual that an entity represents
# Aliases:
# Question forms:
#
# ####
# # 194.
# PID: P706
# Label: находится в пределах природно-географического объекта
# Count: 25526
# Description: место расположено на территории некого водоёма или элемента ландшафта (значения свойства не должны быть единицами административно-террит
# Aliases:
# расположен в пределах природно-географического объекта
# расположена в пределах природно-географического объекта
# расположено в пределах природно-географического объекта
# в
# в пределах
# в рамках
# внутри
# местонахождение:
# местоположение:
# находится в
# находится в пределах географического объекта
# посреди
# среди
# Question forms:
#
# ####
# # 195.
# PID: P1103
# Label: число железнодорожных путей у платформ
# Count: 25438
# Description: number of tracks served by a platform at a railway station
# Aliases:
# Question forms:
# ####
# # 196.
# PID: P412
# Label: певческий голос
# Count: 25326
# Description: person's voice type. expected values: soprano, mezzo-soprano, contralto, countertenor, tenor, baritone, bass (and derivatives)
# Aliases:
# голос
# тембр
# Question forms:
#
# ####
# # 197.
# PID: P1618
# Label: номер игрока
# Count: 24799
# Description: номер на одежде участника спортивного состязания
# Aliases:
# Question forms:
#
# ####
# # 198.
# PID: P2053
# Label: площадь бассейна
# Count: 24751
# Description: площадь, с которой собираются воды в данный водный объект
# Aliases:
# бассейн водоёма
# площадь бассейна водоёма
# Question forms:
#
# ####
# # 199.
# PID: P1249
# Label: первое письменное упоминание
# Count: 24723
# Description: дата, когда объект был впервые упомянут в письменном источнике
# Aliases:
# впервые упоминается
# дата первого упоминания
# первое упоминание
# Question forms:
#
# ####
# # 200.
# PID: P1813
# Label: короткое название
# Count: 23627
# Description: сокращённое название места, организации, персоны и т. д.
# Aliases:
# аббревиатура
# акроним
# короткое имя
# краткое название
# название короткое
# сокращение
# Question forms:
#
# ####
# # 201.
# PID: P5051
# Label: по направлению к
# Count: 22040
# Description: qualifier for "adjacent station" (P197) to indicate the terminal station(s) of a transportation line or service in that direction
# Aliases:
# направление
# Question forms:
#
# ####
# # 202.
# PID: P1824
# Label: номер дороги
# Count: 21996
# Description: number assigned to a stretch of public roadway
# Aliases:
# номер автомагистрали
# номер шоссе
# обозначение дороги
# Question forms:
#
# ####
# # 203.
# PID: P2079
# Label: метод изготовления
# Count: 21831
# Description: используемый метод, процесс, техника изготовления, сборки или готовки
# Aliases:
# изготавливается посредством или с помощью
# инструмент:
# метод производства:
# посредством
# производится методом
# производится посредством или с помощью
# производственный процесс:
# процесс изготовления:
# с помощью
# способ изготовления:
# способ или средство изготовления
# способ производства:
# способ
# средство или инструмент:
# способ:
# средство изготовления:
# средство:
# чем изготавливается:
# чем производится:
# чем:
# Question forms:
#
# ####
# # 204.
# PID: P144
# Label: создано на основе
# Count: 21227
# Description: то, что послужило идеей, базой, основой
# Aliases:
# исходная работа
# на основе
# оригинальная работа
# основа
# основано на
# первоначальная работа
# по мотивам
# производное от
# прототип
# форк
# Question forms:
#
# ####
# # 205.
# PID: P559
# Label: конечная
# Count: 21139
# Description: объект в конце линейного субъекта (например, Т-образный перекрёсток или конечная станция)
# Aliases:
# заканчивается
# конец
# конечная
# конечная станция
# окончание
# Question forms:
#
# ####
# # 206.
# PID: P404
# Label: режим игры
# Count: 21000
# Description: доступный игровой режим или режимы в компьютерной игре
# Aliases:
# игровой режим
# Question forms:
#
# ####
# # 207.
# PID: P974
# Label: впадающие водотоки
# Count: 20912
# Description: водотоки (реки и ручьи), впадающие в водоток или озеро
# Aliases:
# впадают
# притоки
# Question forms:
#
# ####
# # 208.
# PID: P1066
# Label: обучался у
# Count: 20797
# Description: человек, который научил предмету
# Aliases:
# был учеником
# проходил обучение у
# студент кого
# ученик кого
# учился у
# учитель
# учителя
# чей студент
# Question forms:
#
# ####
# # 209.
# PID: P3602
# Label: кандидат на выборах
# Count: 20784
# Description: election where the subject is a candidate
# Aliases:
# участвовал в выборах
# Question forms:
#
# ####
# # 210.
# PID: P2701
# Label: формат файла
# Count: 19663
# Description: file format, compression type, or ontology used in a file
# Aliases:
# Question forms:
#
# ####
# # 211.
# PID: P6
# Label: глава правительства
# Count: 19453
# Description: высшее административное лицо, глава исполнительного органа города, муниципалитета, страны или другой правительственной структуры
# Aliases:
# бургомистр
# глава администрации самоуправляемой территории
# глава города
# глава исполнительной власти
# глава кабинета министров
# глава коммуны
# глава муниципального образования
# глава общины
# градоначальник
# губернатор
# мэр
# правительство возглавляет
# президент территориальной единицы
# премьер-министр
# префект
# Question forms:
#
# ####
# # 212.
# PID: P1411
# Label: номинирован на
# Count: 19176
# Description: award nomination received by a person, organisation or creative work (inspired from "award received" (Property:P166))
# Aliases:
# номинирована на
# Question forms:
#
# ####
# # 213.
# PID: P2416
# Label: спортивная дисциплина
# Count: 18811
# Description: спортивная дисциплина, в которой атлет принимал участие
# Aliases:
# участник соревнований по
# Question forms:
#
# ####
# # 214.
# PID: P915
# Label: место съёмок
# Count: 18581
# Description: actual place where this scene/film was shot. For the setting, use "narrative location" (P840)
# Aliases:
# Question forms:
#
# ####
# # 215.
# PID: P729
# Label: дата принятия в эксплуатацию
# Count: 18504
# Description: дата, когда деталь или оборудование начало операционную деятельность
# Aliases:
# пуск
# введено
# время пуска
# выпущено
# запущено
# начало
# принято в эксплуатацию
# производится с
# пущено
# стартовано
# точка начала во времени
# эксплуатируется с
# Question forms:
#
# ####
# # 216.
# PID: P437
# Label: распространение произведения
# Count: 18498
# Description: у творческой работы: её метод распространения или носитель
# Aliases:
# дистрибуция
# медиум
# носитель
# Question forms:
#
# ####
# # 217.
# PID: P2959
# Label: постоянный дубликат
# Count: 18219
# Description: обычно для связи двух статей в одном проекте Викимедиа об одном и том же (но на другом диалекте или в другом алфавите)
# Aliases:
# дубликат
# Question forms:
#
# ####
# # 218.
# PID: P183
# Label: является эндемиком в
# Count: 17716
# Description: sole location or habitat type where the taxon lives
# Aliases:
# Question forms:
#
# ####
# # 219.
# PID: P184
# Label: научный руководитель
# Count: 17703
# Description: человек, курировавший подготовку диссертации персоны
# Aliases:
# научрук
# руководитель
# Question forms:
#
# ####
# # 220.
# PID: P2960
# Label: дата архивирования
# Count: 17281
# Description: date a document was archived
# Aliases:
# Question forms:
#
# ####
# # 221.
# PID: P466
# Label: обитатель
# Count: 17147
# Description: личность или организация, занимающая данное здание или сооружение
# Aliases:
# занято организацией
# Question forms:
#
# ####
# # 222.
# PID: P609
# Label: расположение конечной точки
# Count: 17124
# Description: location of the terminus of a linear feature
# Aliases:
# Question forms:
#
# ####
# # 223.
# PID: P664
# Label: организатор
# Count: 16940
# Description: лицо или организация, устроившие данное мероприятие
# Aliases:
# Question forms:
#
# ####
# # 224.
# PID: P205
# Label: бассейн объекта в странах
# Count: 16824
# Description: country that have drainage to/from or border the body of water
# Aliases:
# Question forms:
#
# ####
# # 225.
# PID: P485
# Label: архивы хранятся в
# Count: 16730
# Description: организация, в которой хранятся архивы персоны
# Aliases:
# Question forms:
#
# ####
# # 226.
# PID: P1313
# Label: должность главы правительства
# Count: 16700
# Description: political office that is fulfilled by the head of the government of this item
# Aliases:
# Question forms:
#
# ####
# # 227.
# PID: P2031
# Label: начало периода активности
# Count: 16693
# Description: начало периода, в который персона или группа проводила профессиональную активность
# Aliases:
# дата начала активности
# начало активности
# начало деятельности
# начало периода деятельности
# рабочий период начало
# Question forms:
#
# ####
# # 228.
# PID: P1111
# Label: получено голосов
# Count: 16468
# Description: число голосов, полученных кандидатом на выборах
# Aliases:
# голосов получено
# количество голосов
# получил голосов
# число голосов
# Question forms:
#
# ####
# # 229.
# PID: P1080
# Label: из вымышленного мира
# Count: 16388
# Description: вымышленный мир, которому принадлежит объект
# Aliases:
# в вымышленной вселенной
# в мире
# вымышленный мир:
# из вымышленной вселенной
# из мира
# мир:
# Question forms:
#
# ####
# # 230.
# PID: P2789
# Label: соединяется с
# Count: 16249
# Description: указывает на соединение дорог, улиц, площадей и пр.
# Aliases:
# дороги соединения
# маршруты соединения
# перекресток с
# перекрёсток с
# пересекает
# соединен с
# соединена с
# соединено с
# соединён с
# стыкуется с
# улицы соединения
# Question forms:
#
# ####
# # 231.
# PID: P1416
# Label: принадлежит к
# Count: 15745
# Description: принадлежность: организация, к которой относится элемент
# Aliases:
# аффилиация
# относится к организации
# Question forms:
#
# ####
# # 232.
# PID: P190
# Label: город-побратим
# Count: 15570
# Description: город, с которым у данного города установлены постоянные дружественные отношения
# Aliases:
# города-побратимы
# побратим
# породненный город
# породнённый город
# Question forms:
#
# ####
# # 233.
# PID: P742
# Label: псевдоним
# Count: 15115
# Description: псевдоним, используемый кем-либо или под которым этот человек известен
# Aliases:
# Question forms:
#
# ####
# # 234.
# PID: P88
# Label: заказчик произведения
# Count: 14988
# Description: person or organization that commissioned this work
# Aliases:
# заказчик
# Question forms:
#
# ####
# # 235.
# PID: P4510
# Label: используется в описываемом проекте
# Count: 14956
# Description: essential component or tool that was used in the project described in this publication
# Aliases:
# описывает проект
# использующий
# Question forms:
#
# ####
# # 236.
# PID: P629
# Label: является изданием или переводом
# Count: 14516
# Description: ссылка на элемент про сам текст (книгу)
# Aliases:
# издание
# является изданием
# является переводом
# Question forms:
#
# ####
# # 237.
# PID: P1552
# Label: обладает свойством
# Count: 14438
# Description: неотделимое свойство, которое нельзя передать
# Aliases:
# каково:
# какое:
# кандидат на создание свойства:
# качество
# неотделимое свойство
# неотъемлемое свойство
# обладает качеством
# обладает характеристикой
# обязательное свойство
# свойство:
# характерная черта
# черта
# Question forms:
#
# ####
# # 238.
# ...
# # 527.
# PID: P2842
# Label: место свадьбы
# Count: 1666
# Description: место, где совершалось бракосочетание. Квалификатор для свойства P26 "супруг(а)"
# Aliases:
# Question forms:
#
# ####
# # 528.
# PID: P3300
# Label: дирижёр
# Count: 1664
# Description: the person who directs a musical group, orchestra or chorus
# Aliases:
# дирижер
# Question forms:
#
# ####
# # 529.
# PID: P5191
# Label: происходит от
# Count: 1662
# Description: лексема, от которой происходит данная
# Aliases:
# создано на основе
# образовано от
# восходит к
# этимон
# Question forms:
#
# ####
# # 530.
# PID: P748
# Label: кем назначен
# Count: 1660
# Description: кто назначен или избрал персону на должность
# Aliases:
# избран
# кем избран
# назначен
# Question forms:
#
# ####
# # 531.
# PID: P1354
# Label: изображённый элемент
# Count: 1657
# Description: secondary features depicted in a work. Use as qualifier for "depicts" (P180)
# Aliases:
# изображённые элементы
# изображённый объект
# Question forms:
#
# ####
# # 532.
# PID: P3087
# Label: налоговые поступления
# Count: 1641
# Description: fiscal revenue of a public entity
# Aliases:
# налогов
# Question forms:
#
# ####
# # 533.
# PID: P2884
# Label: сетевое напряжение
# Count: 1607
# Description: напряжение в бытовой электрической сети данной страны или региона
# Aliases:
# напряжение
# Question forms:
#
# ####
# # 534.
# PID: P3919
# Label: является соавтором опубликованной работы
# Count: 1597
# Description: person is cited as contributing to some creative or published work or series (qualify with "subject has role", P2868)
# Aliases:
# автор
# автор опубликованной работы
# произведение
# соавтор
# является автором опубликованной работы
# Question forms:
#
# ####
# # 535.
# PID: P5028
# Label: sound designer
# Count: 1594
# Description: person responsible for the sound on a stage, in a film or in a radio drama
# Aliases:
# Question forms:
#
# ####
# # 536.
# PID: P2522
# Label: победа
# Count: 1582
# Description: соревнование, которое выиграл субъект
# Aliases:
# победил
# победила
# победило
# Question forms:
#
# ####
# # 537.
# PID: P658
# Label: композиции
# Count: 1579
# Description: композиции данного альбома
# Aliases:
# треклист
# Question forms:
#
# ####
# # 538.
# PID: P765
# Label: тип покрытия
# Count: 1567
# Description: тип покрытия, на котором проходят игры чемпионата
# Aliases:
# Question forms:
#
# ####
# # 539.
# PID: P1387
# Label: позиция в политическом спектре
# Count: 1537
# Description: political position within the political spectrum
# Aliases:
# политическая позиция
# Question forms:
#
# ####
# # 540.
# PID: P2139
# Label: общая выручка
# Count: 1526
# Description: income gained by an organization during a given time frame. not to be confused with fiscal revenue
# Aliases:
# выручка
# оборот
# Question forms:
#
# ####
# # 541.
# PID: P879
# Label: номер вымпела
# Count: 1513
# Description: буквенно-цифровое обозначение, присваиваемое кораблю на время службы, часто выкрашено на корпусе
# Aliases:
# Question forms:
#
# ####
# # 542.
# PID: P1885
# Label: собор
# Count: 1511
# Description: principal church of a religious district
# Aliases:
# Question forms:
#
# ####
# # 543.
# PID: P2146
# Label: орбитальный период
# Count: 1473
# Description: это период времени, который требуется объекту-спутнику для совершения полного оборота относительно другого тела (звезды, планеты)
# Aliases:
# период обращения
# сидерический период
# Question forms:
#
# ####
# # 544.
# PID: P91
# Label: сексуальная ориентация
# Count: 1459
# Description: the sexual orientation of the person — use IF AND ONLY IF they have stated it themselves, unambiguously, or it has been widely agreed upon by historians after their death
# Aliases:
# Question forms:
#
# ####
# # 545.
# PID: P1308
# Label: должность занимает
# Count: 1453
# Description: человек, занимающий данную должность
# Aliases:
# в должности
# занимает
# у власти
# Question forms:
#
# ####
# # 546.
# PID: P5314
# Label: используется как
# Count: 1453
# Description: квалификатор системы ограничений для определения области применения свойства
# Aliases:
# область применения свойства
# Question forms:
#
# ####
# # 547.
# PID: P2243
# Label: апоцентр
# Count: 1451
# Description: наиболее удалённая от центрального тела точка орбиты
# Aliases:
# апоапсида
# апоастр
# апогей
# апогелий
# афелий
# Question forms:
#
# ####
# # 548.
# PID: P2244
# Label: перицентр
# Count: 1439
# Description: ближайшая к центральному телу точка орбиты
# Aliases:
# периапсида
# периастр
# перигей
# перигелий
# Question forms:
#
# ####
# # 549.
# PID: P4900
# Label: более широкое понятие
# Count: 1435
# Description: qualifier to indicate a broader concept that the present item is part of, as mapped by an external source. The statement being qualified should be an exact match.
# Aliases:
# более общее понятие
# общее понятие
# широкое понятие
# Question forms:
#
# ####
# # 550.
# PID: P837
# Label: день в году
# Count: 1426
# Description: день, в который отмечается праздник или происходит периодическое событие. Может использоваться как свойство или квалификатор
# Aliases:
# день в году для периодических событий
# день года
# Question forms:
#
# ####
# # 551.
# PID: P1098
# Label: число носителей языка
# Count: 1420
# Description: число людей, которые говорят на этом языке
# Aliases:
# количество носителей языка
# носителей языка
# языком владеет
# языком разговаривает
# Question forms:
#
# ####
# # 552.
# PID: P792
# Label: глава в книге
# Count: 1415
# Description: title or number of the chapter where a claim is made
# Aliases:
# Question forms:
#
# ####
# # 553.
# PID: P5816
# Label: охранный статус
# Count: 1411
# Description: to indicate state of conservation of a building, monument, etc. It is not related with its heritage protection (p1435), but to its present state of conservation. Ex.: ruinous, demolished, correct, etc.
# Aliases:
# состояние сохраненности
# сохранность
# Question forms:
#
# ####
# # 554.
# PID: P1358
# Label: очков в турнирной таблице
# Count: 1407
# Description: количество набранных очков в чемпионате или декатлоне. Для очков в отдельном матче используйте P1351
# Aliases:
# Question forms:
#
# ####
# # 555.
# PID: P38
# Label: денежная единица
# Count: 1394
# Description: валюта, используемая в стране
# Aliases:
# валюта
# денежная единица
# деньги
# Question forms:
#
# ####
# # 556.
# PID: P5053
# Label: быстрейший круг
# Count: 1382
# Description: человек, который выполнил самый быстрый круг в мотогонке
# Aliases:
# обладатель быстрейшего круга
# Question forms:
#
# ####
# # 557.
# PID: P111
# Label: физическая величина
# Count: 1376
# Description: физическое свойство, измеряемое данной единицей
# Aliases:
# измеряемая величина
# физическое свойство
# Question forms:
#
# ####
# # 558.
# PID: P157
# Label: кто убил
# Count: 1375
# Description: лицо, которое убило
# Aliases:
# кем убит
# убийца
# убит
# Question forms:
#
# ####
# # 559.
# PID: P3321
# Label: мужская форма наименования
# Count: 1375
# Description: male form of name of an element
# Aliases:
# мужская форма обозначения
# Question forms:
#
# ####
# # 560.
# PID: P2545
# Label: стиль подачи мяча в крикете
# Count: 1373
# Description: type of bowling employed by a cricketer
# Aliases:
# Question forms:
#
# ####
# # 561.
# PID: P5054
# Label: кабинет
# Count: 1355
# Description: квалификатор для «занимаемая должность» (P39) для указания кабинета, к которому принадлежит министр
# Aliases:
# кабинет министров
# Question forms:
#
# ####
# # 562.
# PID: P2595
# Label: наибольший уклон
# Count: 1354
# Description: maximum gradient on a route, expressed as a percentage
# Aliases:
# максимальный градиент
# наибольший градиент
# уклон
# Question forms:
#
# ####
# # 563.
# PID: P2076
# Label: температура
# Count: 1350
# Description: квалификатор, указывающий температуру, при которой верно утверждение
# Aliases:
# при температуре
# Question forms:
#
# ####
# # 564.
# PID: P4132
# Label: языковая типология
# Count: 1350
# Description: classification of languages according to their linguistic trait (as opposed to historical families like romance languages)
# Aliases:
# Question forms:
#
# ####
# # 565.
# PID: P483
# Label: записано на
# Count: 1336
# Description: студия, где была записана музыкальная композиция
# Aliases:
# Question forms:
#
# ####
# # 566.
# PID: P2142
# Label: кассовые сборы
# Count: 1331
# Description: суммарные сборы фильма от проката в кинотеатрах
# Aliases:
# бокс-офис
# кассовый сбор
# сбор
# сборы
# театральная касса
# Question forms:
#
# ####
# # 567.
# PID: P3780
# Label: является активным ингредиентов в
# Count: 1328
# Description: is part of and forms biologically active component. Inverse of "has active ingredient"
# Aliases:
# Question forms:
#
# ####
# # 568.
# PID: P2284
# Label: цена
# Count: 1300
# Description: published price listed or paid for a product (use with unit of currency)
# Aliases:
# Question forms:
#
# ####
# # 569.
# PID: P689
# Label: поражает
# Count: 1279
# Description: тип организма, которого поражает болезнь
# Aliases:
# Question forms:
#
# ####
# # 570.
# PID: P2895
# Label: максимальные стабильные ветры
# Count: 1279
# Description: maximum sustained wind evaluated by agency
# Aliases:
# максимальный стабильный ветер
# Question forms:
#
# ####
# # 571.
# PID: P3871
# Label: сторона притока
# Count: 1277
# Description: является ли приток левым или правым
# Aliases:
# Question forms:
#
# ####
# # 572.
# PID: P5623
# Label: type of water supply
# Count: 1276
# Description: the type of water supply for fountains, mountain huts, and other entities where water can be obtained
# Aliases:
# Question forms:
#
# ####
# # 573.
# PID: P505
# Label: генеральный менеджер
# Count: 1257
# Description: генеральный менеджер спортивной команды. Если менеджер осуществляет также непосредственное управление командой на поле, используйте P286
# Aliases:
# Question forms:
#
# ####
# # 574.
# PID: P2436
# Label: электрическое напряжение
# Count: 1257
# Description: difference in electric potential between two points (indicated in volt)
# Aliases:
# вольтаж
# Question forms:
#
# ####
# # 575.
# PID: P208
# Label: исполнительная власть
# Count: 1230
# Description: часть правительства, ответственная за ежедневное управление государством
# Aliases:
# Question forms:
#
# ####
# # 576.
# PID: P122
# Label: форма правления
# Count: 1204
# Description: subject's government
# Aliases:
# Question forms:
#
# ####
# # 577.
# PID: P2532
# Label: нижнее давление
# Count: 1202
# Description: минимальное атмосферное давление урагана
# Aliases:
# минимальное атмосферное давление
# Question forms:
#
# ####
# # 578.
# PID: P2176
# Label: лекарство, используемое для лечения
# Count: 1201
# Description: drug, procedure, or therapy that can be used to treat a medical condition
# Aliases:
# используется для лечения
# лекарство для лечения
# Question forms:
#
# ####
# # 579.
# PID: P1725
# Label: ударов в минуту
# Count: 1191
# Description: темп музыкального произведения
# Aliases:
# BPM
# Question forms:
#
# ####
# # 580.
# PID: P552
# Label: рабочая рука
# Count: 1188
# Description: может принимать значения «правша (Q3039938)», «левша (Q789447)» или «амбидекстрия (Q457332)»
# Aliases:
# ведущая рука
# играющая рука
# преобладающая рука
# рабочая рука
# рука
# Question forms:
#
# ####
# # 581.
# PID: P4296
# Label: скорость вращения звезды
# Count: 1185
# Description: measured parameter for stars
# Aliases:
# Question forms:
#
# ####
# # 582.
# PID: P2572
# Label: хештег Твиттера
# Count: 1175
# Description: Twitter hashtag associated with this entity. Format: do not include the "#" symbol
# Aliases:
# хештег Twitter
# хештег Твиттер
# хэштег Twitter
# хэштег Твиттер
# Question forms:
#
# ####
# # 583.
# PID: P2109
# Label: выходная мощность
# Count: 1172
# Description: мощность, которую может выдавать двигатель
# Aliases:
# мощность
# Question forms:
#
# ####
# # 584.
# PID: P2233
# Label: большая полуось
# Count: 1164
# Description: наибольшее удаление точки эллипса от его центра
# Aliases:
# Question forms:
#
# ####
# # 585.
# PID: P1773
# Label: приписываемый автор
# Count: 1162
# Description: возможный создатель произведения, которому оно обычно приписывается
# Aliases:
# Question forms:
#
# ####
# # 586.
# PID: P2184
# Label: история темы
# Count: 1152
# Description: элемент, в котором описана история объекта
# Aliases:
# Question forms:
#
# ####
# # 587.
# PID: P770
# Label: причина разрушения
# Count: 1149
# Description: item which caused the destruction of the subject item
# Aliases:
# Question forms:
#
# ####
# # 588.
# PID: P1314
# Label: число пролётов
# Count: 1147
# Description: число пролётов моста
# Aliases:
# Question forms:
#
# ####
# # 589.
# PID: P1596
# Label: наказание
# Count: 1140
# Description: по приговору суда
# Aliases:
# Question forms:
#
# ####
# # 590.
# PID: P5389
# Label: постоянный резидент
# Count: 1124
# Description: country or region that person have the legal status of permanent resident
# Aliases:
# Question forms:
#
# ####
# # 591.
# PID: P5027
# Label: number of representations
# Count: 1106
# Description: number of shows (including the premiere) of a concert tour or a performing arts production
# Aliases:
# Question forms:
#
# ####
# # 592.
# PID: P3095
# Label: практикуется
# Count: 1054
# Description: кем
# Aliases:
# работник этой отрасли называется
# Question forms:
#
# ####
# # 593.
# PID: P2562
# Label: имя в браке
# Count: 1050
# Description: имя или фамилия, принятая при вступлении в брак
# Aliases:
# имя в замужестве
# Question forms:
#
# ####
# # 594.
# PID: P4633
# Label: имя персонажа роли
# Count: 1046
# Description: name by which a character role is recorded in a database or mentioned in the context of a work, use as qualifier for cast
# Aliases:
# Question forms:
#
# ####
# # 595.
# PID: P780
# Label: симптомы
# Count: 1041
# Description: возможные симптомы медицинского состояния
# Aliases:
# Question forms:
#
# ####
# # 596.
# PID: P1639
# Label: пандан для
# Count: 1041
# Description: произведение искусства, парное с другим (например, свадебные портреты жениха и невесты)
# Aliases:
# парный для
# Question forms:
#
# ####
# # 597.
# PID: P1049
# Label: божество относится к
# Count: 1039
# Description: религия или цивилизация, почитающая это божество
# Aliases:
# Question forms:
#
# ####
# # 598.
# PID: P263
# Label: официальная резиденция
# Count: 1034
# Description: официальное местонахождение главы правительства, президента и других высокопоставленных лиц
# Aliases:
# резиденция
# Question forms:
#
# ####
# # 599.
# PID: P2054
# Label: плотность
# Count: 1032
# Description: плотность вещества, с указанием в квалификаторах агрегатного состояния и температуры
# Aliases:
# Question forms:
#
# ####
# # 600.
# PID: P3342
# Label: значимый человек
# Count: 1025
# Description: персона, каким-либо образом связанная с элементом
# Aliases:
# значимая персона
# значительная персона
# значительное лицо
# ключевой участник
# Question forms:
#
# ####
# # 601.
# PID: P4602
# Label: дата погребения или кремации
# Count: 1025
# Description: date on which the person was buried or cremated soon after death
# Aliases:
# дата кремации
# дата погребения
# Question forms:
#
# ####
# # 602.
# PID: P4241
# Label: уточнение даты
# Count: 1024
# Description: qualifier to narrow down the precision of a date not fully specified by the Wikidata time datatype precision field
# Aliases:
# Question forms:
#
# ####
# # 603.
# PID: P2101
# Label: температура плавления
# Count: 1021
# Description: температура, при которой вещество переходит из твёрдого в жидкое состояние
# Aliases:
# температура кристаллизации
# точка кристаллизации
# точка плавления
# Question forms:
#
# ####
# # 604.
# PID: P554
# Label: адрес в социальных медиа
# Count: 1002
# Description: имя пользователя в социальных медиа (используется с P553)
# Aliases:
# адрес в социальной сети
# адрес в соцсети
# Question forms:
#
# ####
# # 605.
# PID: P5238
# Label: слагается из
# Count: 970
# Description: лексемы, из которых слагается сложное слово
# Aliases:
# складывается из
# состоит из
# составлено из
# Question forms:
#
# ####
# # 606.
# PID: P3150
# Label: день рождения
# Count: 957
# Description: используется, когда известен день и месяц рождения, но неизвестен год
# Aliases:
# Question forms:
#
# ####
# # 607.
# PID: P2295
# Label: чистая прибыль
# Count: 956
# Description: private entity profit
# Aliases:
# прибыль
# Question forms:
#
# ####
# # 608.
# PID: P193
# Label: основная строительная организация
# Count: 948
# Description: the main organization responsible for construction of this structure or building
# Aliases:
# Question forms:
#
# ####
# # 609.
# PID: P1299
# Label: изображается на
# Count: 946
# Description: где изображается данный объект
# Aliases:
# изображена на
# изображено на
# изображён на
# Question forms:
#
# ####
# # 610.
# PID: P2579
# Label: изучается в
# Count: 924
# Description: какой наукой или дисциплиной изучается или исследуется предмет
# Aliases:
# изучается дисциплиной
# исследуется в
# наука
# которая изучает этот предмет
# Question forms:
#
# ####
# # 611.
# PID: P2669
# Label: дата окончания поддержки
# Count: 911
# Description: дата окончания официальной поддержки продукта
# Aliases:
# дата завершения поддержки
# дата прекращения поддержки
# завершение поддержки
# окончание поддержки
# поддержка завершена
# поддержка прекращена
# прекращение поддержки
# Question forms:
#
# ####
# # 612.
# PID: P4250
# Label: установленная суточная доза
# Count: 911
# Description: average maintenance dose per day for a medicine used for its main indication in adults
# Aliases:
# Question forms:
#
# ####

# %% [markdown]
# Generate properties PID-label json

# %%
pids = []
for ind, row in popular_and_good_properties.iterrows():
    pids.append((row['ID'], row['label']))
with open('pids.json', 'w') as ouf:
    json.dump(pids, ouf, ensure_ascii=False, indent=4)
